# %%
import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib

# %%
data_dir = '../data'

df_nasdaq = pd.read_csv(f'{data_dir}/nasdaq.csv', parse_dates=['Date'], index_col='Date')

# %%
df_nasdaq.drop(columns="Volume").plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df_nasdaq[["Volume"]].plot()
# Out:
# <AxesSubplot: xlabel='Date'>
